# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

print("VS Code is now using the correct Python environment! 🚀")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# VS Code is now using the correct Python environment! 🚀
